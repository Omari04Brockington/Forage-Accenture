# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import uuid

# %matplotlib inline

# %%
df = pd.read_csv('/Users/odawg2004/Desktop/ReactionTypes.csv', na_values=['', '?', '-'], names = ["Sentiment", "State", "Score"], index_col=False)

# %%
df
# Out:
#       Sentiment     State  Score
# 0     Sentiment     State  Score
# 1         heart  positive     60
# 2          want  positive     70
# 3       disgust  negative      0
# 4          hate  negative      5
# 5    interested  positive     30
# 6   indifferent   neutral     20
# 7          love  positive     65
# 8    super love  positive     75
# 9       cherish  positive     70
# 10        adore  positive     72
# 11         like  positive     50
# 12      dislike  negative     10
# 13    intrigued  positive     45
# 14      peeking   neutral     35
# 15       scared  negative     15
# 16      worried  negative     12

# %%
df = df.drop(0)

# %%
df
# Out:
#       Sentiment     State Score
# 1         heart  positive    60
# 2          want  positive    70
# 3       disgust  negative     0
# 4          hate  negative     5
# 5    interested  positive    30
# 6   indifferent   neutral    20
# 7          love  positive    65
# 8    super love  positive    75
# 9       cherish  positive    70
# 10        adore  positive    72
# 11         like  positive    50
# 12      dislike  negative    10
# 13    intrigued  positive    45
# 14      peeking   neutral    35
# 15       scared  negative    15
# 16      worried  negative    12

# %%
df.drop('Type', axis=1, inplace=True)

# %%
df
# Out:
#       Sentiment     State Score
# 1         heart  positive    60
# 2          want  positive    70
# 3       disgust  negative     0
# 4          hate  negative     5
# 5    interested  positive    30
# 6   indifferent   neutral    20
# 7          love  positive    65
# 8    super love  positive    75
# 9       cherish  positive    70
# 10        adore  positive    72
# 11         like  positive    50
# 12      dislike  negative    10
# 13    intrigued  positive    45
# 14      peeking   neutral    35
# 15       scared  negative    15
# 16      worried  negative    12

# %%
df.dtypes
# Out:
# Sentiment    object
# State        object
# Score        object
# dtype: object

# %%
df['Score'] = df['Score'].astype(int)

# %%
df.dtypes
# Out:
# Sentiment     object
# State         object
# Score        float64
# dtype: object

# %%
data = pd.read_csv('/Users/odawg2004/Desktop/Reactions.csv')

# %%
data = data.drop(0)

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust  2021-01-06 19:13:01
# ...

# %%
data['Type'] = data['Type'].astype(str)

# %%
data.dtypes
# Out:
# Content ID    object
# User ID       object
# Type          object
# Datetime      object
# dtype: object

# %%
data['Datetime'] = pd.to_datetime(data['Datetime'])

# %%
data
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust 2021-01-06 19:13:01
# ...

# %%
data.dtypes
# Out:
# Content ID            object
# User ID               object
# Type                  object
# Datetime      datetime64[ns]
# dtype: object

# %%
data = data.dropna()

# %%
data
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust 2021-01-06 19:13:01
# ...

# %%
data['User ID'] = data['User ID'].astype(str).apply(lambda x: str(uuid.uuid5(uuid.NAMESPACE_DNS, x)))

# %%
dataframe = pd.read_csv('/Users/odawg2004/Desktop/Content.csv')

# %%
dataframe
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
dataframe.drop('Unnamed: 0', axis=1, inplace=True)
dataframe.drop('Type', axis=1, inplace=True)

# %%
dataframe
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4   healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf       technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1             food
# ..                                    ...              ...
# ...

# %%
dataframe = dataframe.dropna()

# %%
dataframe
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID        Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31        Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf      technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1            food
# ..                                    ...             ...
# ...

# %%
dataframe.drop('URL', axis=1, inplace=True)
# Out:
# <ipython-input-64-1646cb2001ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe.drop('URL', axis=1, inplace=True)

# %%
dataframe.dtypes
# Out:
# Content ID    object
# User ID       object
# Category      object
# dtype: object

# %%
df.to_csv('/Users/odawg2004/Desktop/ReactionTypes.csv', index=False, header=True, encoding='utf-8')

# %%
data.to_csv('/Users/odawg2004/Desktop/Reactions.csv', index=False, header=True, encoding='utf-8')

# %%
dataframe.to_csv('/Users/odawg2004/Desktop/Content.csv', index=False, header=True, encoding='utf-8')
